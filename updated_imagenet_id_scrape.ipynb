# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
def fetch_and_save_mapping(url, table_selector, output_file):
    # Fetch the webpage
    response = requests.get(url)
    if response.status_code != 200:
        print("Failed to fetch the page")
        return

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    print(soup)
    table = soup.select_one(table_selector)  # Use CSS selector to find the table

    if not table:
        print("Table not found")
        return

    # Extract data from the table rows
    data = {}
    for row in table.find_all('tr'):
        columns = row.find_all('td')
        if len(columns) > 1:  # Assuming at least two columns for ID and mapping
            old_id = columns[0].text.strip()
            word = columns[1].text.strip()
            data[word] = old_id

    # Save data to a JSON file
    with open(output_file, 'w') as f:
        json.dump(data, f, indent=4)

    print(f"Data saved to {output_file}")

# %%
# Usage example
url = 'https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/'
table_selector = 'table'  # Adjust the CSS selector based on the actual table's attributes
output_file = 'new_word_to_id_mapping.json'
fetch_and_save_mapping(url, table_selector, output_file)
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en" > <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="../../../img/favicon.ico" rel="shortcut icon"/>
# <title>IMAGENET 1000 Class List - WekaDeeplearning4j</title>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700|Roboto+Slab:400,700|Inconsolata:400,700" rel="stylesheet" type="text/css"/>
# <link href="../../../css/theme.css" rel="stylesheet" type="text/css">
# <link href="../../../css/theme_extra.css" rel="stylesheet" type="text/css">
# <link href="//cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/styles/github.min.css" rel="stylesheet"/>
# <script>
#     // Current page data
#     var mkdocs_page_name = "IMAGENET 1000 Class List";
# ...
